# %% [raw]
# supervised learning
# classification and expression tasks
# Ensembling methods  ----> process of combining the multiple decision tree or classifiers to solve a complex task
# improves the performance of ghe model
# it is similar to decision trees

# %% [raw]
# steps involved in random forest
# 1. selects the random samples from the dataset
# 2. the algorithm will design tree for each
# 3. Voting will take place by averaging theh decision tree

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\zubai\Downloads\heart_v2.csv")

# %%
df
# Out:
#      age  sex   BP  cholestrol  heart disease
# 0     70    1  130         322              1
# 1     67    0  115         564              0
# 2     57    1  124         261              1
# 3     64    1  128         263              0
# 4     74    0  120         269              0
# ..   ...  ...  ...         ...            ...
# 265   52    1  172         199              0
# 266   44    1  120         263              0
# 267   56    0  140         294              0
# 268   57    1  140         192              0
# 269   67    1  160         286              1
#
# [270 rows x 5 columns]
